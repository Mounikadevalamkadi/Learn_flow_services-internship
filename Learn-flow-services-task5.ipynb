# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step:1 Goals and Objectives

# %% [markdown]
# Goal: Increase brand engagement
#
# Objective: Identify top influencers for collaboration

# %% [markdown]
# # Step:2 Select social media platform

# %% [markdown]
# Social Media Platforms: Twitter

# %% [markdown]
# # Step:3 Data Collection

# %% [markdown]
# ## Load dataset

# %%
df=pd.read_csv("C:\\Users\mounika\OneDrive\Desktop\Twitterdatainsheets.csv")

# %% [markdown]
# ## Understanding data

# %%
df
# Out:
#          index                TweetID   Weekday  Hour  Day  Lang  IsReshare  \
# 0            0  tw-682712873332805633  Thursday    17   31    en      False
# 1            1  tw-682713045357998080  Thursday    17   31    en       True
# 2            2  tw-682713219375476736  Thursday    17   31    en      False
# 3            3  tw-682713436967579648  Thursday    17   31    en      False
# 4            4  tw-682714048199311366  Thursday    17   31    en      False
# ...        ...                    ...       ...   ...  ...   ...        ...
# 206290  206290           tw-443876086    Female   NaN  NaN   NaN        NaN
# 206291  206291           tw-565013710   Unknown   NaN  NaN   NaN        NaN
# 206292  206292           tw-322341885    Female   NaN  NaN   NaN        NaN
# 206293  206293          tw-3304550634      Male   NaN  NaN   NaN        NaN
# 206294  206294                    NaN       NaN   NaN  NaN   NaN        NaN
#
# ...

# %%
df.head()
# Out:
#    index                TweetID   Weekday  Hour  Day  Lang  IsReshare   Reach  \
# 0      0  tw-682712873332805633  Thursday    17   31    en      False    44.0
# 1      1  tw-682713045357998080  Thursday    17   31    en       True  1810.0
# 2      2  tw-682713219375476736  Thursday    17   31    en      False   282.0
# 3      3  tw-682713436967579648  Thursday    17   31    en      False  2087.0
# 4      4  tw-682714048199311366  Thursday    17   31    en      False   953.0
#
#     RetweetCount   Likes   Klout   Sentiment  \
# 0            0.0     0.0    35.0         0.0
# 1            5.0     0.0    53.0         2.0
# 2            0.0     0.0    47.0         0.0
# 3            4.0     0.0    53.0         0.0
# 4            0.0     0.0    47.0         0.0
#
#                                                 text   LocationID  \
# 0  We are hiring: Senior Software Engineer - Prot...       3751.0
# 1  RT @CodeMineStatus: This is true Amazon Web Se...       3989.0
# ...

# %%
df.tail()
# Out:
#          index        TweetID  Weekday  Hour  Day  Lang  IsReshare   Reach  \
# 206290  206290   tw-443876086   Female   NaN  NaN   NaN        NaN     NaN
# 206291  206291   tw-565013710  Unknown   NaN  NaN   NaN        NaN     NaN
# 206292  206292   tw-322341885   Female   NaN  NaN   NaN        NaN     NaN
# 206293  206293  tw-3304550634     Male   NaN  NaN   NaN        NaN     NaN
# 206294  206294            NaN      NaN   NaN  NaN   NaN        NaN     NaN
#
#          RetweetCount   Likes   Klout   Sentiment  text   LocationID  UserID
# 206290            NaN     NaN     NaN         NaN   NaN          NaN     NaN
# 206291            NaN     NaN     NaN         NaN   NaN          NaN     NaN
# 206292            NaN     NaN     NaN         NaN   NaN          NaN     NaN
# 206293            NaN     NaN     NaN         NaN   NaN          NaN     NaN
# 206294            NaN     NaN     NaN         NaN   NaN          NaN     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206295 entries, 0 to 206294
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   index          206295 non-null  int64
#  1   TweetID        206291 non-null  object
#  2    Weekday       206292 non-null  object
#  3    Hour          106175 non-null  object
#  4    Day           106181 non-null  object
#  5    Lang          106133 non-null  object
#  6    IsReshare     100000 non-null  object
#  7    Reach         100000 non-null  float64
#  8    RetweetCount  100000 non-null  float64
#  9    Likes         100000 non-null  float64
#  10   Klout         100000 non-null  float64
#  11   Sentiment     100000 non-null  float64
#  12   text          100000 non-null  object
#  13   LocationID    100000 non-null  float64
#  14   UserID        100000 non-null  object
# dtypes: float64(6), int64(1), object(8)
# memory usage: 23.6+ MB

# %%
df.shape
# Out:
# (206295, 15)

# %%
df.describe()
# Out:
#                index         Reach   RetweetCount          Likes  \
# count  206295.000000  1.000000e+05  100000.000000  100000.000000
# mean   103147.000000  8.542396e+03       8.052750       0.152770
# std     59552.381229  8.867027e+04      97.863474       2.583633
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%     51573.500000  1.510000e+02       0.000000       0.000000
# 50%    103147.000000  4.485000e+02       0.000000       0.000000
# 75%    154720.500000  1.496000e+03       3.000000       0.000000
# max    206294.000000  1.034245e+07   26127.000000     133.000000
#
#                Klout      Sentiment     LocationID
# count  100000.000000  100000.000000  100000.000000
# mean       40.389260       0.380921    2836.163440
# std        13.636513       1.046559    1323.140242
# min         0.000000      -6.000000       1.000000
# 25%        32.000000       0.000000    1601.000000
# 50%        43.000000       0.000000    3738.000000
# ...

# %%
df.columns
# Out:
# Index(['index', 'TweetID', ' Weekday', ' Hour', ' Day', ' Lang', ' IsReshare',
#        ' Reach', ' RetweetCount', ' Likes', ' Klout', ' Sentiment', ' text',
#        ' LocationID', ' UserID'],
#       dtype='object')

# %%
# Clean up column names
df.columns = df.columns.str.strip()
# Check the cleaned column names
df.columns
# Out:
# Index(['index', 'TweetID', 'Weekday', 'Hour', 'Day', 'Lang', 'IsReshare',
#        'Reach', 'RetweetCount', 'Likes', 'Klout', 'Sentiment', 'text',
#        'LocationID', 'UserID'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
#  Identify Missing Values

# %%
df.isnull().sum()
# Out:
# index                 0
# TweetID               4
#  Weekday              3
#  Hour            100120
#  Day             100114
#  Lang            100162
#  IsReshare       106295
#  Reach           106295
#  RetweetCount    106295
#  Likes           106295
#  Klout           106295
#  Sentiment       106295
#  text            106295
#  LocationID      106295
#  UserID          106295
# dtype: int64

# %% [markdown]
#  datatypes

# %%
df.dtypes
# Out:
# index              int64
# TweetID           object
#  Weekday          object
#  Hour             object
#  Day              object
#  Lang             object
#  IsReshare        object
#  Reach           float64
#  RetweetCount    float64
#  Likes           float64
#  Klout           float64
#  Sentiment       float64
#  text             object
#  LocationID      float64
#  UserID           object
# dtype: object

# %%
# Drop rows with missing values for specific columns
df_cleaned = df.dropna(subset=['TweetID', 'Weekday', 'Hour', 'Day', 'Lang'])
# Display the shape of the cleaned DataFrame
print("Shape after handling missing values:", df_cleaned.shape)
# Out:
# Shape after handling missing values: (106128, 15)

# %%
# Define numeric_columns based on the numeric columns in your DataFrame
numeric_columns = ['Hour', 'Day', 'IsReshare', 'Reach', 'RetweetCount', 'Likes', 'Klout', 'Sentiment', 'LocationID']
# Convert numeric columns to appropriate data types using .loc
df_cleaned.loc[:, numeric_columns] = df_cleaned[numeric_columns].apply(pd.to_numeric, errors='coerce')
# Display the data types after conversion
print("\nData Types after conversion:")
print(df_cleaned.dtypes)
# Check for missing values again
missing_values_cleaned = df_cleaned.isnull().sum()
print("\nMissing Values after cleaning:")
print(missing_values_cleaned)
# Out:
# Data Types after conversion:
# index             int64
# TweetID          object
# Weekday          object
# Hour             object
# Day              object
# Lang             object
# IsReshare        object
# Reach           float64
# RetweetCount    float64
# Likes           float64
# Klout           float64
# Sentiment       float64
# text             object
# LocationID      float64
# UserID           object
# dtype: object
#
# Missing Values after cleaning:
# index              0
# TweetID            0
# Weekday            0
# Hour            6128
# Day             6128
# Lang               0
# IsReshare       6128
# Reach           6128
# RetweetCount    6128
# Likes           6128
# Klout           6128
# Sentiment       6128
# text            6128
# LocationID      6128
# UserID          6128
# dtype: int64

# %%
# Impute missing values for numeric columns using .loc
df_cleaned.loc[:, numeric_columns] = df_cleaned.loc[:, numeric_columns].apply(lambda x: x.fillna(x.mean()))
# Display the DataFrame after imputation
df_cleaned.head()
# Out:
#    index                TweetID   Weekday  Hour   Day Lang IsReshare   Reach  \
# 0      0  tw-682712873332805633  Thursday  17.0  31.0   en       0.0    44.0
# 1      1  tw-682713045357998080  Thursday  17.0  31.0   en       1.0  1810.0
# 2      2  tw-682713219375476736  Thursday  17.0  31.0   en       0.0   282.0
# 3      3  tw-682713436967579648  Thursday  17.0  31.0   en       0.0  2087.0
# 4      4  tw-682714048199311366  Thursday  17.0  31.0   en       0.0   953.0
#
#    RetweetCount  Likes  Klout  Sentiment  \
# 0           0.0    0.0   35.0        0.0
# 1           5.0    0.0   53.0        2.0
# 2           0.0    0.0   47.0        0.0
# 3           4.0    0.0   53.0        0.0
# 4           0.0    0.0   47.0        0.0
#
#                                                 text  LocationID  \
# 0  We are hiring: Senior Software Engineer - Prot...      3751.0
# 1  RT @CodeMineStatus: This is true Amazon Web Se...      3989.0
# ...

# %% [markdown]
# # Step 4: Identify Key Metrics

# %%
# Use pandas to analyze key metrics
key_metrics = df[['Reach', 'RetweetCount', 'Likes', 'Sentiment', 'Klout']]
# Display basic statistics
print(key_metrics.describe())
# Out:
#               Reach   RetweetCount          Likes      Sentiment  \
# count  1.000000e+05  100000.000000  100000.000000  100000.000000
# mean   8.542396e+03       8.052750       0.152770       0.380921
# std    8.867027e+04      97.863474       2.583633       1.046559
# min    0.000000e+00       0.000000       0.000000      -6.000000
# 25%    1.510000e+02       0.000000       0.000000       0.000000
# 50%    4.485000e+02       0.000000       0.000000       0.000000
# 75%    1.496000e+03       3.000000       0.000000       0.666667
# max    1.034245e+07   26127.000000     133.000000       7.333333
#
#                Klout
# count  100000.000000
# mean       40.389260
# std        13.636513
# min         0.000000
# 25%        32.000000
# 50%        43.000000
# 75%        49.000000
# max        99.000000

# %% [markdown]
# # Step 5: Influencer Identification

# %%
# Identify influencers based on Klout score
influencers = df[df['Klout'] > df['Klout'].mean()]
# Display the influencers
print(influencers[['UserID', 'Klout']])
# Out:
#               UserID  Klout
# 1      tw-3179389829   53.0
# 2      tw-4624808414   47.0
# 3       tw-356447127   53.0
# 4      tw-3172686669   47.0
# 8       tw-202281478   49.0
# ...              ...    ...
# 99987   tw-264165471   46.0
# 99990   tw-124030974   57.0
# 99994  tw-3316009302   44.0
# 99995  tw-4667163978   49.0
# 99998    tw-21826302   42.0
#
# [59404 rows x 2 columns]

# %% [markdown]
# # Step 6: Measure Engagement

# %%
import matplotlib.pyplot as plt

# Plot engagement metrics
plt.figure(figsize=(10, 6))
plt.scatter(df['RetweetCount'], df['Likes'])
plt.xlabel('Retweet Count')
plt.ylabel('Likes')
plt.title('Engagement Scatter Plot')
plt.show()

# %% [markdown]
# # Step 7: Sentiment Analysis

# %%
import matplotlib.pyplot as plt

# Count sentiments
sentiment_counts = df['Sentiment'].value_counts()

# Plot sentiment distribution with stacked bar chart
plt.figure(figsize=(8, 5))
sentiment_counts.plot(kind='bar', color=['red', 'green', 'blue'])
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Analysis')
plt.show()
print(sentiment_counts)
# Out:
# Sentiment
#  0.000000    67424
#  1.000000     8771
#  2.000000     8587
#  3.000000     3945
# -1.000000     1770
#              ...
#  0.164000        1
# -0.271462        1
#  0.186667        1
# -0.140000        1
#  0.136351        1
# Name: count, Length: 309, dtype: int64

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import seaborn as sns
import matplotlib.pyplot as plt

# Download the VADER lexicon for sentiment analysis
nltk.download('vader_lexicon')

# Initialize the SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Assuming 'text' is the column containing the tweets
df_cleaned['SentimentScore'] = df_cleaned['text'].dropna().apply(lambda x: sia.polarity_scores(x)['compound'])

# Visualize sentiment distribution
plt.figure(figsize=(10, 6))

# Check if 'SentimentScore' is present in the DataFrame
if 'SentimentScore' in df_cleaned.columns:
    sns.histplot(df_cleaned['SentimentScore'], bins=30, kde=True)
    plt.title('Distribution of Sentiment Scores in Tweets')
    plt.xlabel('Sentiment Score')
    plt.ylabel('Frequency')
    plt.show()
else:
    print("Error: 'SentimentScore' column not found in the DataFrame.")
print(df_cleaned.columns)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\mounika\AppData\Roaming\nltk_data...
# Index(['index', 'TweetID', 'Weekday', 'Hour', 'Day', 'Lang', 'IsReshare',
#        'Reach', 'RetweetCount', 'Likes', 'Klout', 'Sentiment', 'text',
#        'LocationID', 'UserID', 'SentimentScore'],
#       dtype='object')

# %% [markdown]
# ## Step 8: Trend Analysis

# %%
import seaborn as sns

# Plot trends
plt.figure(figsize=(12, 6))
sns.countplot(x='Weekday', data=df)
plt.xlabel('Weekday')
plt.ylabel('Count')
plt.title('Post Count by Weekday')
plt.show()

# %% [markdown]
# ## Step 9: Competitor Analysis

# %%
# Assuming 'Lang' is the column specifying the language for each tweet
df_cleaned['Lang'] = df_cleaned['Lang'].fillna('Unknown')  # Fill missing values with 'Unknown' if any

# Visualize sentiment scores using a violin plot with improved text visibility
plt.figure(figsize=(14, 8))
sns.violinplot(x='Lang', y='SentimentScore', data=df_cleaned, palette='viridis', inner='quartile')  # Use inner='quartile' to show quartiles
plt.title('Sentiment Scores Distribution by Language (Violin Plot)')
plt.xlabel('Language')
plt.ylabel('Sentiment Score')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from being cut off
plt.xticks(fontsize=10)  # Adjust font size for x-axis labels
plt.yticks(fontsize=12)  # Adjust font size for y-axis labels
plt.show()

# %% [markdown]
# ## Step 10: Content Analysis

# %%
# You can perform content analysis using NLP techniques.
# For simplicity, let's display the most frequent words in the 'text' column.
from wordcloud import WordCloud

text = ' '.join(df['text'].dropna())
wordcloud = WordCloud(width=800, height=400, random_state=21, max_font_size=110).generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Step 11: Create User Personas

# %%
# Create user personas based on influential UserIDs
user_personas = df[df['UserID'].isin(influencers['UserID'])]

# Display user personas
print(user_personas[['UserID', 'Klout', 'Sentiment']])
# Out:
#               UserID  Klout  Sentiment
# 1      tw-3179389829   53.0        2.0
# 2      tw-4624808414   47.0        0.0
# 3       tw-356447127   53.0        0.0
# 4      tw-3172686669   47.0        0.0
# 8       tw-202281478   49.0        0.0
# ...              ...    ...        ...
# 99987   tw-264165471   46.0        0.0
# 99990   tw-124030974   57.0        0.0
# 99994  tw-3316009302   44.0        0.0
# 99995  tw-4667163978   49.0        1.0
# 99998    tw-21826302   42.0        0.0
#
# [62675 rows x 3 columns]

# %% [markdown]
# ## Step 12: Strategic Recommendations

# %% [markdown]
#  No specific code, provide strategic recommendations based on the analysis.
# #For example:
# Recommendation: Collaborate with top influencers for upcoming campaigns.

# %% [markdown]
# ## Step 13: Visualizations

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'Sentiment' is a categorical column in your DataFrame
# Replace 'Sentiment' with the actual column name representing categories
sns.pairplot(df_cleaned.sample(n=500), hue='Sentiment', diag_kind='kde', markers='.', palette='viridis')
plt.suptitle('Pairplot for Numeric Columns with Categorical Hue (Subsample)', y=1.02)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns for correlation calculation
numeric_columns = df_cleaned.select_dtypes(include=['number']).columns
numeric_data = df_cleaned[numeric_columns]

# Compute the correlation matrix for numeric columns
correlation_matrix = numeric_data.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Create a heatmap with the correlation values
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)

plt.title('Correlation Heatmap for Numeric Columns')
plt.show()

# %%
# Scatter plots for numeric columns vs. engagement metrics
engagement_columns = ['Reach', 'RetweetCount', 'Likes']

plt.figure(figsize=(16, 12))

for i, engagement_metric in enumerate(engagement_columns):
    plt.subplot(3, 1, i + 1)
    
    # Select only numeric columns for the scatter plot
    numeric_columns_subset = df_cleaned.select_dtypes(include=['number'])
    
    # Scatter plot for each numeric column against the engagement metric
    for column in numeric_columns_subset.columns:
        sns.scatterplot(x=column, y=engagement_metric, data=df_cleaned)
    
    plt.title(f'Scatter Plots: {engagement_metric} vs. Numeric Columns')
    plt.xlabel('Numeric Columns')
    plt.ylabel(engagement_metric)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Hourly Analysis
plt.figure(figsize=(16, 5))
sns.boxplot(x='Hour', y='Reach', data=df_cleaned, showfliers=False, palette='viridis')  # Excluding outliers for better visibility
plt.title('Hourly Analysis of Tweet Reach')
plt.xlabel('Hour of Day')
plt.ylabel('Tweet Reach')
plt.show()

# Daily Analysis
plt.figure(figsize=(16, 5))
sns.boxplot(x='Day', y='Reach', data=df_cleaned, showfliers=False, palette='viridis')
plt.title('Daily Analysis of Tweet Reach')
plt.xlabel('Day of Week')
plt.ylabel('Tweet Reach')
plt.show()

# %%
# Sentiment Analysis
plt.figure(figsize=(10, 6))
sns.boxplot(x='Sentiment', y='Reach', data=df_cleaned)
plt.title('Sentiment Analysis of Tweet Reach')
plt.show()

# %%
# Klout Analysis
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Klout', y='Reach', data=df_cleaned)
plt.title('Klout Analysis of Tweet Reach')
plt.show()

# %%
from wordcloud import WordCloud

# Combine text from all tweets
all_text = ' '.join(df_cleaned['text'].dropna())

# Create a WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Display the WordCloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Tweet Text')
plt.show()
